# %%
import numpy as np
import pandas as pd

# %%
with open ('/home/m/MGP/maestria/proyecto_tesis/baseline/Palabras_proto/clinical-prescores.csv', 'r') as f:
    df = pd.read_csv(f)

# %%
df
# Out:
#      Unnamed: 0          word  c-prescore
# 0             0  lormetazepam        -5.0
# 1             1            mg        -5.0
# 2             2   mirtazapina        -5.0
# 3             3    fluoxetina        -5.0
# 4             4    alprazolam        -5.0
# ..          ...           ...         ...
# 334         334   aclaratorio         2.0
# 335         335        limpié         2.0
# 336         336     practicas         2.0
# 337         337        claros         2.0
# 338         338     convierte         2.0
#
# [339 rows x 3 columns]

# %%
df['c-prescore'].value_counts()
# Out:
# c-prescore
# -4.0    86
# -3.0    67
#  4.0    52
#  3.0    40
# -5.0    38
#  5.0    24
# -2.0    16
#  2.0    15
# -1.0     1
# Name: count, dtype: int64

# %%
with open ('/home/m/MGP/maestria/proyecto_tesis/baseline/EmoPro/13428_2020_1519_MOESM2_ESM.csv', 'r') as f:
    EmoPro = pd.read_csv(f)

# %%
EmoPro
# Out:
#                 Word Few_Raters  Prototypicality_Mean  Prototypicality_SD  \
# 0         abandonado        NaN                  2.35                1.27
# 1        abandonarse        NaN                  2.00                1.10
# 2           abandono        NaN                  2.38                1.50
# 3            abatido        NaN                  3.37                1.42
# 4        abatimiento        NaN                  3.00                1.37
# ...              ...        ...                   ...                 ...
# 1281           vital        NaN                  2.09                1.38
# 1282       vitalidad        NaN                  2.05                1.10
# 1283       vitalizar        NaN                  1.89                1.10
# 1284  vulnerabilidad        NaN                  2.29                1.45
# 1285      vulnerable        NaN                  2.45                1.47
#
#       Prototypicality_NRaters  Prototypicality_%Raters  Valence_Mean  \
# ...

# %%
Counts = EmoPro['Valence_Mean'].value_counts()

# %%
contenedores = np.arange(0.5, 9., 4.)

frec = pd.cut(EmoPro['Valence_Mean'], contenedores)

tabla_frec = frec.value_counts()
tabla_frec
# Out:
# Valence_Mean
# (0.5, 4.5]    781
# (4.5, 8.5]    498
# Name: count, dtype: int64

# %%
contenedores
# Out:
# array([1.])
